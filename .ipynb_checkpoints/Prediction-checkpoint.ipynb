# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Reading The Data
data = pd.read_csv('data/facebook_stock.csv', index_col='Date', parse_dates = True)

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...                ...         ...         ...         ...         ...
# 2020-04-23  184.080002  187.050003  183.149994  185.130005  185.130005
# 2020-04-24  183.229996  190.410004  180.830002  190.070007  190.070007
# 2020-04-27  192.660004  193.750000  187.410004  187.500000  187.500000
# 2020-04-28  188.660004  189.199997  182.559998  182.910004  182.910004
# 2020-04-29  190.929993  196.910004  190.000000  194.190002  194.190002
#
#                Volume
# Date
# 2012-05-18  573576400
# 2012-05-21  168192700
# 2012-05-22  101786600
# 2012-05-23   73600000
# 2012-05-24   50237200
# ...               ...
# 2020-04-23   21426600
# 2020-04-24   28868500
# 2020-04-27   29197800
# 2020-04-28   21731000
# 2020-04-29   45490500
#
# [1999 rows x 6 columns]

# %%
# Checking for NAN OR Missing Values
data.isna().any()
# Out:
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
# Visualizing The Data
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6))

plt.title("Facebook's Stock Market")
plt.xlabel('Date')
plt.ylabel('Prices')

plt.plot(data['Open'], label='Open', linewidth=2, color='red')
plt.plot(data['Close'], label='Close', linewidth=2, color='blue')

plt.legend()
plt.show()

# %%
# Visualizing The Data
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6))

plt.title("Facebook's Stock Market")
plt.xlabel('Date')
plt.ylabel('Prices')

plt.plot(data['High'], label='High', linewidth=2, color='purple')
plt.plot(data['Low'], label='Low', linewidth=2, color='green')

plt.legend()
plt.show()

# %%
# Splitting The Data Into Training, Testing Data
training_data = data[data.index < '2019-01-01']
testing_data = data[data.index >= '2019-01-01']

testing_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02  128.990005  137.509995  128.559998  135.679993  135.679993
# 2019-01-03  134.690002  137.169998  131.119995  131.740005  131.740005
# 2019-01-04  134.009995  138.000000  133.750000  137.949997  137.949997
# 2019-01-07  137.559998  138.869995  135.910004  138.050003  138.050003
# 2019-01-08  139.889999  143.139999  139.539993  142.529999  142.529999
# ...                ...         ...         ...         ...         ...
# 2020-04-23  184.080002  187.050003  183.149994  185.130005  185.130005
# 2020-04-24  183.229996  190.410004  180.830002  190.070007  190.070007
# 2020-04-27  192.660004  193.750000  187.410004  187.500000  187.500000
# 2020-04-28  188.660004  189.199997  182.559998  182.910004  182.910004
# 2020-04-29  190.929993  196.910004  190.000000  194.190002  194.190002
#
#               Volume
# Date
# 2019-01-02  28146200
# 2019-01-03  22717900
# 2019-01-04  29002100
# 2019-01-07  20089300
# 2019-01-08  26263800
# ...              ...
# 2020-04-23  21426600
# 2020-04-24  28868500
# 2020-04-27  29197800
# 2020-04-28  21731000
# 2020-04-29  45490500
#
# [334 rows x 6 columns]

# %%
# Filtering The DataFrame
training_data = training_data.filter(['Open', 'High', 'Low', 'Close', 'Volume'])
training_data
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2012-05-18   42.049999   45.000000   38.000000   38.230000  573576400
# 2012-05-21   36.529999   36.660000   33.000000   34.029999  168192700
# 2012-05-22   32.610001   33.590000   30.940001   31.000000  101786600
# 2012-05-23   31.370001   32.500000   31.360001   32.000000   73600000
# 2012-05-24   32.950001   33.209999   31.770000   33.029999   50237200
# ...                ...         ...         ...         ...        ...
# 2018-12-24  123.099998  129.740005  123.019997  124.059998   22066000
# 2018-12-26  126.000000  134.240005  125.889999  134.179993   39723400
# 2018-12-27  132.440002  134.990005  129.669998  134.520004   31202500
# 2018-12-28  135.339996  135.919998  132.199997  133.199997   22627600
# 2018-12-31  134.449997  134.639999  129.949997  131.089996   24625300
#
# [1665 rows x 5 columns]

# %%
# Normalizing The Data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_training_data = scaler.fit_transform(training_data)

scaled_training_data
# Out:
# array([[0.12128111, 0.13341652, 0.10395486, 0.10261801, 1.        ],
#        [0.09335154, 0.09178937, 0.07853803, 0.08159383, 0.28587298],
#        [0.07351751, 0.07646619, 0.0680663 , 0.06642639, 0.16889149],
#        ...,
#        [0.57862782, 0.58258052, 0.56994711, 0.58462234, 0.04455   ],
#        [0.59330093, 0.58722237, 0.58280803, 0.5780147 , 0.02944439],
#        [0.5887978 , 0.58083355, 0.57137045, 0.56745255, 0.03296355]])

# %%
# Spitting The Data Into X_train, y_train
X_train = []
y_train = []

for i in range(60, scaled_training_data.shape[0]):
    X_train.append(scaled_training_data[i-60:i])
    y_train.append(scaled_training_data[i,[0, 3]])

# %%
# Converting Lists Into Numpy Arrays
X_train, y_train = np.array(X_train), np.array(y_train)

X_train.shape, y_train.shape
# Out:
# ((1605, 60, 5), (1605, 2))

# %% [markdown]
# ## Building The Model

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error

# %%
model = Sequential()

# Adding the first LSTM layer & Dropout
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))

# Adding the second LSTM layer & Dropout
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding the third LSTM layer & Dropout
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding the fourth LSTM layer & Dropout
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

# Adding the fifth LSTM layer & Dropout
model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Adding the final Dense layer
model.add(Dense(units = 2))

# %%
# Summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 60, 50)            11200
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 60, 50)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 60, 50)            20200
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 60, 50)            0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 60, 50)            20200
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 60, 50)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 60, 50)            20200
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 60, 50)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 92,102
# Trainable params: 92,102
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile The Model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Train The Model
model.fit(X_train, y_train, epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 1605/1605 [==============================] - 17s 11ms/sample - loss: 0.0283
# Epoch 2/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0054
# Epoch 3/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0045
# Epoch 4/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0045
# Epoch 5/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0041
# Epoch 6/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0043
# Epoch 7/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0041
# Epoch 8/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0038
# Epoch 9/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0036
# Epoch 10/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0035
# Epoch 11/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0035
# Epoch 12/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0030
# Epoch 13/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0032
# Epoch 14/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0030
# Epoch 15/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0025
# Epoch 16/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0026
# Epoch 17/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0024
# Epoch 18/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0028
# Epoch 19/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0027
# Epoch 20/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0028
# Epoch 21/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0023
# Epoch 22/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0023
# Epoch 23/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0021
# Epoch 24/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0023
# Epoch 25/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0022
# Epoch 26/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0019
# Epoch 27/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0021
# Epoch 28/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0024
# Epoch 29/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0019
# Epoch 30/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0020
# Epoch 31/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0020
# Epoch 32/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0020
# Epoch 33/150
# 1605/1605 [==============================] - 14s 9ms/sample - loss: 0.0018
# Epoch 34/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0018
# Epoch 35/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0018
# Epoch 36/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0018
# Epoch 37/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0016
# Epoch 38/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0018
# Epoch 39/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0020
# Epoch 40/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0018
# Epoch 41/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0016
# Epoch 42/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0015
# Epoch 43/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0016
# Epoch 44/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0019
# Epoch 45/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0016
# Epoch 46/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0016
# Epoch 47/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 48/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0014
# Epoch 49/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0016
# Epoch 50/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0016
# Epoch 51/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0016
# Epoch 52/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 53/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0017
# Epoch 54/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0014
# Epoch 55/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 56/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0015
# Epoch 57/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 58/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0014
# Epoch 59/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 60/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0012
# Epoch 61/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 62/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 63/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 64/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 65/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 66/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 67/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0013
# Epoch 68/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 69/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0012
# Epoch 70/150
# 1605/1605 [==============================] - 14s 9ms/sample - loss: 0.0012
# Epoch 71/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0012
# Epoch 72/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0014
# Epoch 73/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 74/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 75/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 76/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0011
# Epoch 77/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 78/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 79/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 80/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 81/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 82/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 83/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 84/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 85/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 86/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 87/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0011
# Epoch 88/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 89/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 90/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0012
# Epoch 91/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 92/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.8660e-04
# Epoch 93/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 94/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 95/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 9.7908e-04
# Epoch 96/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 97/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0011
# Epoch 98/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.6687e-04
# Epoch 99/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.0878e-04
# Epoch 100/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0011
# Epoch 101/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.8078e-04
# Epoch 102/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.1276e-04
# Epoch 103/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.7552e-04
# Epoch 104/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 9.7727e-04
# Epoch 105/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0012
# Epoch 106/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 107/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 108/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.5351e-04
# Epoch 109/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.1616e-04
# Epoch 110/150
# 1605/1605 [==============================] - 14s 9ms/sample - loss: 8.8455e-04
# Epoch 111/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.1684e-04
# Epoch 112/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.8263e-04
# Epoch 113/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.7223e-04
# Epoch 114/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.6727e-04
# Epoch 115/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.8005e-04
# Epoch 116/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.8137e-04
# Epoch 117/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.3471e-04
# Epoch 118/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.1135e-04
# Epoch 119/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.6610e-04
# Epoch 120/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.1415e-04
# Epoch 121/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.1683e-04
# Epoch 122/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.5601e-04
# Epoch 123/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.5539e-04
# Epoch 124/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.1686e-04
# Epoch 125/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 9.0177e-04
# Epoch 126/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 9.3474e-04
# Epoch 127/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.4320e-04
# Epoch 128/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.3226e-04
# Epoch 129/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.9255e-04
# Epoch 130/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.7216e-04
# Epoch 131/150
# 1605/1605 [==============================] - 14s 9ms/sample - loss: 8.9284e-04
# Epoch 132/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 7.8005e-04
# Epoch 133/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 7.9718e-04
# Epoch 134/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 0.0010
# Epoch 135/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 9.1414e-04
# Epoch 136/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.2511e-04
# Epoch 137/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.0719e-04
# Epoch 138/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 9.0130e-04
# Epoch 139/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 0.0010
# Epoch 140/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 9.7602e-04
# Epoch 141/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.8614e-04
# Epoch 142/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 7.6479e-04
# Epoch 143/150
# 1605/1605 [==============================] - 14s 9ms/sample - loss: 8.9001e-04
# Epoch 144/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 8.4841e-04
# Epoch 145/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 8.7982e-04
# Epoch 146/150
# 1605/1605 [==============================] - 14s 9ms/sample - loss: 7.7698e-04
# Epoch 147/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 7.6137e-04
# Epoch 148/150
# 1605/1605 [==============================] - 13s 8ms/sample - loss: 7.7540e-04
# Epoch 149/150
# 1605/1605 [==============================] - 14s 9ms/sample - loss: 9.6861e-04
# Epoch 150/150
# 1605/1605 [==============================] - 14s 8ms/sample - loss: 7.1705e-04

# %%
# Saving The Model
model.save('fb_stock_predictor')

# %% [markdown]
# ## Testing Data Preprocessing

# %%
# Filtering The Test Data
testing_data = testing_data.filter(['Open', 'High', 'Low', 'Close', 'Volume'])
testing_data
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2019-01-02  128.990005  137.509995  128.559998  135.679993  28146200
# 2019-01-03  134.690002  137.169998  131.119995  131.740005  22717900
# 2019-01-04  134.009995  138.000000  133.750000  137.949997  29002100
# 2019-01-07  137.559998  138.869995  135.910004  138.050003  20089300
# 2019-01-08  139.889999  143.139999  139.539993  142.529999  26263800
# ...                ...         ...         ...         ...       ...
# 2020-04-23  184.080002  187.050003  183.149994  185.130005  21426600
# 2020-04-24  183.229996  190.410004  180.830002  190.070007  28868500
# 2020-04-27  192.660004  193.750000  187.410004  187.500000  29197800
# 2020-04-28  188.660004  189.199997  182.559998  182.910004  21731000
# 2020-04-29  190.929993  196.910004  190.000000  194.190002  45490500
#
# [334 rows x 5 columns]

# %%
# Get past 60 days data from the training data
past_60_days_data = training_data.tail(60)

# %%
# Create The New Testing DataFrame
new_testing_data = past_60_days_data.append(testing_data)
new_testing_data
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2018-10-04  161.460007  161.460007  157.350006  158.850006  25739600
# 2018-10-05  159.210007  160.899994  156.199997  157.330002  25744000
# 2018-10-08  155.539993  158.339996  154.389999  157.250000  24046000
# 2018-10-09  157.690002  160.589996  157.419998  157.899994  18844400
# 2018-10-10  156.820007  157.690002  151.309998  151.380005  30610000
# ...                ...         ...         ...         ...       ...
# 2020-04-23  184.080002  187.050003  183.149994  185.130005  21426600
# 2020-04-24  183.229996  190.410004  180.830002  190.070007  28868500
# 2020-04-27  192.660004  193.750000  187.410004  187.500000  29197800
# 2020-04-28  188.660004  189.199997  182.559998  182.910004  21731000
# 2020-04-29  190.929993  196.910004  190.000000  194.190002  45490500
#
# [394 rows x 5 columns]

# %%
# Normalizing The Data
scaled_testing_data = scaler.transform(new_testing_data)
scaled_testing_data
# Out:
# array([[0.72546046, 0.71469933, 0.71065476, 0.7064124 , 0.03492651],
#        [0.71407613, 0.71190416, 0.70480884, 0.69880363, 0.03493426],
#        [0.69550694, 0.69912653, 0.69560795, 0.69840316, 0.03194305],
#        ...,
#        [0.88332323, 0.87586725, 0.86346076, 0.8498273 , 0.04101851],
#        [0.86308441, 0.85315698, 0.8388064 , 0.8268509 , 0.02786493],
#        [0.87456989, 0.89163967, 0.87662666, 0.88331582, 0.06971985]])

# %%
# Splitting The Test Data Into X_test, y_test
X_test = []
y_test = []

for i in range(60, scaled_testing_data.shape[0]):
    X_test.append(scaled_testing_data[i-60:i])
    y_test.append(scaled_testing_data[i,[0,3]])

# %%
# Converting Lists Into Numpy Array
X_test, y_test = np.array(X_test), np.array(y_test)

X_test.shape, y_test.shape
# Out:
# ((334, 60, 5), (334, 2))

# %%
# Evaluate The Model
loss = model.evaluate(X_test, y_test)
loss
# Out:
# 334/334 [==============================] - 2s 5ms/sample - loss: 8.0845e-04
# 0.0008084451860586504

# %% [markdown]
# ## Predictions

# %%
# Load The Model
model = keras.models.load_model('fb_stock_predictor')

# %%
# Make Predictions
predictions = model.predict(X_test)

# Predictions

# %%
# Find The Mean Squared Error
mean_error = mean_squared_error(y_test, predictions)

error
# Out:
# 0.001227233999420824

# %%
# Check Scale
scaler.scale_
# Out:
# array([5.05970449e-03, 4.99126541e-03, 5.08336709e-03, 5.00575662e-03,
#        1.76160763e-09])

# %%
scale_open = 1/5.05970449e-03
scale_close = 1/5.00575662e-03

# %%
# Unscaling The Predictions
predicted_open = predictions[:, 0]
predicted_close = predictions[:, 1]

predicted_open = predicted_open * scale_open
predicted_close = predicted_close * scale_close

# %%
# Unscaling the y_test
actual_open = y_test[:, 0]
actual_close = y_test[:, 1]

actual_open = actual_open * scale_open
actual_close = actual_close * scale_close

# %%
# Create The DataFrame For Actual_Open VS Predicted_Open
new_open_df = pd.DataFrame({"Actual Open": actual_open, "Predicted Open": predicted_open})

new_open_df
# Out:
#      Actual Open  Predicted Open
# 0     110.910005      115.987045
# 1     116.610002      116.241096
# 2     115.929995      115.788338
# 3     119.479998      115.743828
# 4     121.809999      116.497246
# ..           ...             ...
# 329   166.000002      156.139053
# 330   165.149996      159.135361
# 331   174.580004      162.036438
# 332   170.580004      164.756088
# 333   172.849993      165.257019
#
# [334 rows x 2 columns]

# %% [markdown]
# ## Visualizing Open Prices

# %%
# Visualizing The Open Prices
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6))

plt.title("Facebook's Stock Market Predictions")
plt.xlabel('Date')
plt.ylabel('Open Prices')

plt.plot(new_open_df['Actual Open'], label='Actual', linewidth=2, color='blue')
plt.plot(new_open_df['Predicted Open'], label='Predicted', linewidth=2, color='red')

plt.legend()
plt.savefig('facebook_stock_prediction_1.png', dpi=100)
plt.show()

# %%
# Create The DataFrame For Actual_Close VS Predicted_Close
new_close_df = pd.DataFrame({"Actual Close": actual_close, "Predicted Close": predicted_close})

new_close_df
# Out:
#      Actual Close  Predicted Close
# 0      117.949993       116.175125
# 1      114.010005       116.420036
# 2      120.219997       115.959442
# 3      120.320003       115.911331
# 4      124.799999       116.664276
# ..            ...              ...
# 329    167.400005       156.373657
# 330    172.340007       159.414703
# 331    169.770000       162.348404
# 332    165.180004       165.095917
# 333    176.460002       165.577667
#
# [334 rows x 2 columns]

# %%
# Visualizing The Open Prices
sns.set(style='darkgrid')
plt.figure(figsize=(15, 6))

plt.title("Facebook's Stock Market Predictions")
plt.xlabel('Date')
plt.ylabel('Close Prices')

plt.plot(new_close_df['Actual Close'], label='Actual', linewidth=2, color='orange')
plt.plot(new_close_df['Predicted Close'], label='Predicted', linewidth=2, color='purple')

plt.legend()
plt.savefig('facebook_stock_prediction_2.png', dpi=100)
plt.show()
